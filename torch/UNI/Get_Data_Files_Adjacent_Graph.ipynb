# %%
import torch
import torch.nn as nn
import torch_geometric
import torch_geometric.nn as geo_nn
from torch_geometric.data import Data

# %%
from torchvision import datasets, transforms
from torch.nn.functional import binary_cross_entropy

from sklearn.metrics.pairwise import cosine_similarity as cos_sim
from skimage import color

import matplotlib.pyplot as plt
import numpy as np
import sys
import os
import math

from util.image import get_patches
from util.graph import get_adj
from util.CustomDatasets import ImageFolderWithPaths as IFWP

# Decompression Bomb error
import PIL
PIL.Image.MAX_IMAGE_PIXELS = None

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
ENCODER_PATH = './models/encoder.pth'
TRANSFORM_PATH = './models/transform.pth'
encoder = torch.load(ENCODER_PATH).to(device)
transform = torch.load(TRANSFORM_PATH)

transform = transforms.Compose([
    transforms.ToPILImage(), # Convert numpy array to PIL image
    transform,
])
transform
# Out:
# Compose(
#     ToPILImage()
#     Compose(
#     Resize(size=224, interpolation=bilinear, max_size=None, antialias=True)
#     CenterCrop(size=(224, 224))
#     ToTensor()
#     Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
# )
# )

# %%
MAIN_PATH = '/groups/francescavitali/eb2/subImages1/H&E/'

# Full dataset
dataset = IFWP(MAIN_PATH, device=device)

# %%
loader = torch.utils.data.DataLoader(dataset = dataset,
                                            batch_size = 1)

# %%
WHITE_IMG = color.rgb2gray(np.zeros((224, 224, 3)) + 255)

# %%
with open('progress.txt', 'w') as file:
    file.write(f"Starting graph creation:\n")

THRESHOLD = 1 - 1e-3 # by inspection seems good ._.

all_patients_dict = {}
img_idx = 0
prev_id = None
label = None

# For each encoding in the loader
for img, label, path in loader:
    
    img = img.squeeze(0)
    label = label.to(device)
    
    # Extract the id
    img_id = dataset.get_main_img_id(img_idx)[:-4]
    
    print(f'\n{img_id} ({img_idx+1}/{len(loader)}):\n')
    with open('progress.txt', 'a') as file:
        file.write(f'\n{img_id} ({img_idx+1}/{len(loader)}):\n')
    
    img_idx += 1
    patches, num_w, num_h = get_patches(img)
    
    print(f'{patches.shape=} , {num_w=}, {num_h=}')
    with open('progress.txt', 'a') as file:
        file.write(f'{patches.shape=} , {num_w=}, {num_h=}\n')
    
    enc_list = []
    
    valid_idxs = []
    # Loop over all the patches
    for i in range(num_h):
        for j in range(num_w):
            idx = i * num_w + j
                
            gray_scale = color.rgb2gray(patches[idx])*255

            cos_sim_val = cos_sim([gray_scale.reshape(224*224)], [WHITE_IMG.reshape(224*224)]).item()

            # Ignore images that are similar to white image
            if cos_sim_val > THRESHOLD:
                continue
            else:
                valid_idxs.append(idx)
                
                with torch.no_grad():
                    enc = encoder(transform(patches[idx]).unsqueeze(dim=0).to(device))
                    enc_list.append(enc.squeeze(0).cpu())
            

    # Mapping orig -> new to lookup new idxs
    adjusted_idxs = {orig: new for new, orig in enumerate(valid_idxs)}
    
    edge_list = []
    
    # Loop through and add the correct values to edge_list
    for orig in sorted(valid_idxs):
        adj = get_adj(orig, num_w, num_h)
        
        temp = []
        for neighbor in adj:
            if neighbor in adjusted_idxs:
                temp.append(adjusted_idxs[neighbor])
        edge_list.append(temp)
    
    # Progress debugging
    if img_id in all_patients_dict:
        print(f'{img_id} already in patients dict')
        with open('progress.txt', 'a') as file:
            file.write(f'{img_id} already in patients dict')
            
    # Create the COO format for the edges     
    src = []
    dest = []
    for i, neighbors in enumerate(edge_list):
        for neighbor in neighbors:
            src.append(i)
            dest.append(neighbor)
    
    # Save the information in the dict
    all_patients_dict[img_id] = {'enc': torch.stack(enc_list), 'label': label, 'edge_list': [src, dest]}
    
    torch.cuda.empty_cache()
    torch.cuda.reset_peak_memory_stats()
            
print(f'Amt of imgs: {len(dataset)}')
# Out:
# 001_01 (1/506):
#
# Original shape: torch.Size([6761, 11420, 3])
# New shape: (6944, 11424, 3)
# patches.shape=(1581, 224, 224, 3) , num_w=51, num_h=31
#
# 001_02 (2/506):
#
# Original shape: torch.Size([6706, 12679, 3])
# New shape: (6720, 12768, 3)
# patches.shape=(1710, 224, 224, 3) , num_w=57, num_h=30
#
# 001_03 (3/506):
#
# Original shape: torch.Size([4672, 8125, 3])
# New shape: (4704, 8288, 3)
# patches.shape=(777, 224, 224, 3) , num_w=37, num_h=21
#
# 001_04 (4/506):
#
# Original shape: torch.Size([5625, 5342, 3])
# New shape: (5824, 5376, 3)
# patches.shape=(624, 224, 224, 3) , num_w=24, num_h=26
#
# 001_05 (5/506):
#
# Original shape: torch.Size([4844, 6923, 3])
# New shape: (4928, 6944, 3)
# patches.shape=(682, 224, 224, 3) , num_w=31, num_h=22
#
# 001_06 (6/506):
#
# Original shape: torch.Size([6103, 7000, 3])
# New shape: (6272, 7168, 3)
# patches.shape=(896, 224, 224, 3) , num_w=32, num_h=28
#
# 002_01 (7/506):
#
# Original shape: torch.Size([6445, 15704, 3])
# New shape: (6496, 15904, 3)
# patches.shape=(2059, 224, 224, 3) , num_w=71, num_h=29
#
# 002_02 (8/506):
#
# Original shape: torch.Size([8889, 15142, 3])
# New shape: (8960, 15232, 3)
# patches.shape=(2720, 224, 224, 3) , num_w=68, num_h=40
#
# 002_03 (9/506):
#
# Original shape: torch.Size([15809, 15071, 3])
# New shape: (15904, 15232, 3)
# patches.shape=(4828, 224, 224, 3) , num_w=68, num_h=71
#
# 002_04 (10/506):
#
# Original shape: torch.Size([16187, 9500, 3])
# New shape: (16352, 9632, 3)
# patches.shape=(3139, 224, 224, 3) , num_w=43, num_h=73
#
# 003_01 (11/506):
#
# Original shape: torch.Size([5887, 6627, 3])
# New shape: (6048, 6720, 3)
# patches.shape=(810, 224, 224, 3) , num_w=30, num_h=27
#
# 003_02 (12/506):
#
# Original shape: torch.Size([7431, 6750, 3])
# New shape: (7616, 6944, 3)
# patches.shape=(1054, 224, 224, 3) , num_w=31, num_h=34
#
# 004_01 (13/506):
#
# Original shape: torch.Size([9337, 7273, 3])
# New shape: (9408, 7392, 3)
# patches.shape=(1386, 224, 224, 3) , num_w=33, num_h=42
#
# 004_02 (14/506):
#
# Original shape: torch.Size([4651, 4957, 3])
# New shape: (4704, 5152, 3)
# patches.shape=(483, 224, 224, 3) , num_w=23, num_h=21
#
# 004_03 (15/506):
#
# Original shape: torch.Size([6755, 13297, 3])
# New shape: (6944, 13440, 3)
# patches.shape=(1860, 224, 224, 3) , num_w=60, num_h=31
#
# 004_04 (16/506):
#
# Original shape: torch.Size([6657, 13257, 3])
# New shape: (6720, 13440, 3)
# patches.shape=(1800, 224, 224, 3) , num_w=60, num_h=30
#
# 005_01 (17/506):
#
# Original shape: torch.Size([8292, 13880, 3])
# New shape: (8512, 13888, 3)
# patches.shape=(2356, 224, 224, 3) , num_w=62, num_h=38
#
# 005_02 (18/506):
#
# Original shape: torch.Size([5960, 11484, 3])
# New shape: (6048, 11648, 3)
# patches.shape=(1404, 224, 224, 3) , num_w=52, num_h=27
#
# 005_03 (19/506):
#
# Original shape: torch.Size([6245, 13465, 3])
# New shape: (6272, 13664, 3)
# patches.shape=(1708, 224, 224, 3) , num_w=61, num_h=28
#
# 005_04 (20/506):
#
# Original shape: torch.Size([5591, 13652, 3])
# New shape: (5600, 13664, 3)
# patches.shape=(1525, 224, 224, 3) , num_w=61, num_h=25
#
# 006_01 (21/506):
#
# Original shape: torch.Size([6769, 7772, 3])
# New shape: (6944, 7840, 3)
# patches.shape=(1085, 224, 224, 3) , num_w=35, num_h=31
#
# 006_02 (22/506):
#
# Original shape: torch.Size([6161, 5753, 3])
# New shape: (6272, 5824, 3)
# patches.shape=(728, 224, 224, 3) , num_w=26, num_h=28
#
# 006_03 (23/506):
#
# Original shape: torch.Size([6014, 19014, 3])
# New shape: (6048, 19040, 3)
# patches.shape=(2295, 224, 224, 3) , num_w=85, num_h=27
#
# 006_04 (24/506):
#
# Original shape: torch.Size([5040, 16516, 3])
# New shape: (5152, 16576, 3)
# patches.shape=(1702, 224, 224, 3) , num_w=74, num_h=23
#
# 006_05 (25/506):
#
# Original shape: torch.Size([8830, 5860, 3])
# New shape: (8960, 6048, 3)
# patches.shape=(1080, 224, 224, 3) , num_w=27, num_h=40
#
# 007_01 (26/506):
#
# Original shape: torch.Size([4523, 8882, 3])
# New shape: (4704, 8960, 3)
# patches.shape=(840, 224, 224, 3) , num_w=40, num_h=21
#
# 007_02 (27/506):
#
# Original shape: torch.Size([4723, 2914, 3])
# New shape: (4928, 3136, 3)
# patches.shape=(308, 224, 224, 3) , num_w=14, num_h=22
#
# 007_03 (28/506):
#
# Original shape: torch.Size([10125, 6547, 3])
# New shape: (10304, 6720, 3)
# patches.shape=(1380, 224, 224, 3) , num_w=30, num_h=46
#
# 007_04 (29/506):
#
# Original shape: torch.Size([7554, 14742, 3])
# New shape: (7616, 14784, 3)
# patches.shape=(2244, 224, 224, 3) , num_w=66, num_h=34
#
# 008_01 (30/506):
#
# Original shape: torch.Size([10541, 5838, 3])
# New shape: (10752, 6048, 3)
# patches.shape=(1296, 224, 224, 3) , num_w=27, num_h=48
#
# 008_02 (31/506):
#
# Original shape: torch.Size([6149, 7711, 3])
# New shape: (6272, 7840, 3)
# patches.shape=(980, 224, 224, 3) , num_w=35, num_h=28
#
# 008_03 (32/506):
#
# Original shape: torch.Size([9781, 7616, 3])
# New shape: (9856, 7616, 3)
# patches.shape=(1496, 224, 224, 3) , num_w=34, num_h=44
#
# 008_04 (33/506):
#
# Original shape: torch.Size([11236, 16569, 3])
# New shape: (11424, 16576, 3)
# patches.shape=(3774, 224, 224, 3) , num_w=74, num_h=51
#
# 008_05 (34/506):
#
# Original shape: torch.Size([6810, 11551, 3])
# New shape: (6944, 11648, 3)
# patches.shape=(1612, 224, 224, 3) , num_w=52, num_h=31
#
# 009_01 (35/506):
#
# Original shape: torch.Size([9227, 10176, 3])
# New shape: (9408, 10304, 3)
# patches.shape=(1932, 224, 224, 3) , num_w=46, num_h=42
#
# 009_02 (36/506):
#
# Original shape: torch.Size([10491, 9035, 3])
# New shape: (10528, 9184, 3)
# patches.shape=(1927, 224, 224, 3) , num_w=41, num_h=47
#
# 009_03 (37/506):
#
# Original shape: torch.Size([6757, 8267, 3])
# New shape: (6944, 8288, 3)
# patches.shape=(1147, 224, 224, 3) , num_w=37, num_h=31
#
# 009_04 (38/506):
#
# Original shape: torch.Size([10925, 10626, 3])
# New shape: (10976, 10752, 3)
# patches.shape=(2352, 224, 224, 3) , num_w=48, num_h=49
#
# 009_05 (39/506):
#
# Original shape: torch.Size([10641, 12265, 3])
# New shape: (10752, 12320, 3)
# patches.shape=(2640, 224, 224, 3) , num_w=55, num_h=48
#
# 010_01 (40/506):
#
# Original shape: torch.Size([4033, 7041, 3])
# New shape: (4256, 7168, 3)
# patches.shape=(608, 224, 224, 3) , num_w=32, num_h=19
#
# 010_02 (41/506):
#
# Original shape: torch.Size([9410, 11042, 3])
# New shape: (9632, 11200, 3)
# patches.shape=(2150, 224, 224, 3) , num_w=50, num_h=43
#
# 010_03 (42/506):
#
# Original shape: torch.Size([8567, 12913, 3])
# New shape: (8736, 12992, 3)
# patches.shape=(2262, 224, 224, 3) , num_w=58, num_h=39
#
# 010_04 (43/506):
#
# Original shape: torch.Size([8444, 10359, 3])
# New shape: (8512, 10528, 3)
# patches.shape=(1786, 224, 224, 3) , num_w=47, num_h=38
#
# 010_05 (44/506):
#
# Original shape: torch.Size([7740, 4789, 3])
# New shape: (7840, 4928, 3)
# patches.shape=(770, 224, 224, 3) , num_w=22, num_h=35
#
# 010_06 (45/506):
#
# Original shape: torch.Size([7376, 6220, 3])
# New shape: (7392, 6272, 3)
# patches.shape=(924, 224, 224, 3) , num_w=28, num_h=33
#
# 011_01 (46/506):
#
# Original shape: torch.Size([6803, 13352, 3])
# New shape: (6944, 13440, 3)
# patches.shape=(1860, 224, 224, 3) , num_w=60, num_h=31
#
# 011_02 (47/506):
#
# Original shape: torch.Size([9067, 13649, 3])
# New shape: (9184, 13664, 3)
# patches.shape=(2501, 224, 224, 3) , num_w=61, num_h=41
#
# 011_03 (48/506):
#
# Original shape: torch.Size([10026, 10462, 3])
# New shape: (10080, 10528, 3)
# patches.shape=(2115, 224, 224, 3) , num_w=47, num_h=45
#
# 011_04 (49/506):
#
# Original shape: torch.Size([9389, 8196, 3])
# New shape: (9408, 8288, 3)
# patches.shape=(1554, 224, 224, 3) , num_w=37, num_h=42
#
# 012_01 (50/506):
#
# Original shape: torch.Size([6554, 14640, 3])
# New shape: (6720, 14784, 3)
# patches.shape=(1980, 224, 224, 3) , num_w=66, num_h=30
#
# 012_02 (51/506):
#
# Original shape: torch.Size([8034, 14130, 3])
# New shape: (8064, 14336, 3)
# patches.shape=(2304, 224, 224, 3) , num_w=64, num_h=36
#
# 012_03 (52/506):
#
# Original shape: torch.Size([5028, 7350, 3])
# New shape: (5152, 7392, 3)
# patches.shape=(759, 224, 224, 3) , num_w=33, num_h=23
#
# 012_04 (53/506):
#
# Original shape: torch.Size([7089, 14501, 3])
# New shape: (7168, 14560, 3)
# patches.shape=(2080, 224, 224, 3) , num_w=65, num_h=32
#
# 012_05 (54/506):
#
# Original shape: torch.Size([5696, 7437, 3])
# New shape: (5824, 7616, 3)
# patches.shape=(884, 224, 224, 3) , num_w=34, num_h=26
#
# 013_01 (55/506):
#
# Original shape: torch.Size([11511, 10148, 3])
# New shape: (11648, 10304, 3)
# patches.shape=(2392, 224, 224, 3) , num_w=46, num_h=52
#
# 013_02 (56/506):
#
# Original shape: torch.Size([12366, 10146, 3])
# New shape: (12544, 10304, 3)
# patches.shape=(2576, 224, 224, 3) , num_w=46, num_h=56
#
# 013_03 (57/506):
#
# Original shape: torch.Size([10950, 10009, 3])
# New shape: (10976, 10080, 3)
# patches.shape=(2205, 224, 224, 3) , num_w=45, num_h=49
#
# 013_04 (58/506):
#
# Original shape: torch.Size([10334, 11664, 3])
# New shape: (10528, 11872, 3)
# patches.shape=(2491, 224, 224, 3) , num_w=53, num_h=47
#
# 013_05 (59/506):
#
# Original shape: torch.Size([11410, 12648, 3])
# New shape: (11424, 12768, 3)
# patches.shape=(2907, 224, 224, 3) , num_w=57, num_h=51
#
# 014_01 (60/506):
#
# Original shape: torch.Size([8526, 7003, 3])
# New shape: (8736, 7168, 3)
# patches.shape=(1248, 224, 224, 3) , num_w=32, num_h=39
#
# 014_02 (61/506):
#
# Original shape: torch.Size([7893, 6192, 3])
# New shape: (8064, 6272, 3)
# patches.shape=(1008, 224, 224, 3) , num_w=28, num_h=36
#
# 014_03 (62/506):
#
# Original shape: torch.Size([7586, 7550, 3])
# New shape: (7616, 7616, 3)
# patches.shape=(1156, 224, 224, 3) , num_w=34, num_h=34
#
# 014_04 (63/506):
#
# Original shape: torch.Size([8116, 8174, 3])
# New shape: (8288, 8288, 3)
# patches.shape=(1369, 224, 224, 3) , num_w=37, num_h=37
#
# 014_05 (64/506):
#
# Original shape: torch.Size([7533, 7021, 3])
# New shape: (7616, 7168, 3)
# patches.shape=(1088, 224, 224, 3) , num_w=32, num_h=34
#
# 014_06 (65/506):
#
# Original shape: torch.Size([6597, 7394, 3])
# New shape: (6720, 7616, 3)
# patches.shape=(1020, 224, 224, 3) , num_w=34, num_h=30
#
# 015_01 (66/506):
#
# Original shape: torch.Size([5326, 22656, 3])
# New shape: (5376, 22848, 3)
# patches.shape=(2448, 224, 224, 3) , num_w=102, num_h=24
#
# 015_02 (67/506):
#
# Original shape: torch.Size([7435, 16943, 3])
# New shape: (7616, 17024, 3)
# patches.shape=(2584, 224, 224, 3) , num_w=76, num_h=34
#
# 015_03 (68/506):
#
# Original shape: torch.Size([5848, 6961, 3])
# New shape: (6048, 7168, 3)
# patches.shape=(864, 224, 224, 3) , num_w=32, num_h=27
#
# 015_04 (69/506):
#
# Original shape: torch.Size([5645, 3834, 3])
# New shape: (5824, 4032, 3)
# patches.shape=(468, 224, 224, 3) , num_w=18, num_h=26
#
# 015_05 (70/506):
#
# Original shape: torch.Size([9774, 5348, 3])
# New shape: (9856, 5376, 3)
# patches.shape=(1056, 224, 224, 3) , num_w=24, num_h=44
#
# 015_06 (71/506):
#
# Original shape: torch.Size([8718, 5114, 3])
# New shape: (8736, 5152, 3)
# patches.shape=(897, 224, 224, 3) , num_w=23, num_h=39
#
# 016_01 (72/506):
#
# Original shape: torch.Size([10240, 10069, 3])
# New shape: (10304, 10080, 3)
# patches.shape=(2070, 224, 224, 3) , num_w=45, num_h=46
#
# 016_02 (73/506):
#
# Original shape: torch.Size([9072, 5967, 3])
# New shape: (9184, 6048, 3)
# patches.shape=(1107, 224, 224, 3) , num_w=27, num_h=41
#
# 016_03 (74/506):
#
# Original shape: torch.Size([7764, 11306, 3])
# New shape: (7840, 11424, 3)
# patches.shape=(1785, 224, 224, 3) , num_w=51, num_h=35
#
# 016_04 (75/506):
#
# Original shape: torch.Size([4962, 6852, 3])
# New shape: (5152, 6944, 3)
# patches.shape=(713, 224, 224, 3) , num_w=31, num_h=23
#
# 016_05 (76/506):
#
# Original shape: torch.Size([9238, 9627, 3])
# New shape: (9408, 9632, 3)
# patches.shape=(1806, 224, 224, 3) , num_w=43, num_h=42
#
# 016_06 (77/506):
#
# Original shape: torch.Size([8507, 12337, 3])
# New shape: (8512, 12544, 3)
# patches.shape=(2128, 224, 224, 3) , num_w=56, num_h=38
#
# 016_07 (78/506):
#
# Original shape: torch.Size([13709, 12518, 3])
# New shape: (13888, 12544, 3)
# patches.shape=(3472, 224, 224, 3) , num_w=56, num_h=62
#
# 017_01 (79/506):
#
# Original shape: torch.Size([6583, 7845, 3])
# New shape: (6720, 8064, 3)
# patches.shape=(1080, 224, 224, 3) , num_w=36, num_h=30
#
# 017_02 (80/506):
#
# Original shape: torch.Size([8299, 11610, 3])
# New shape: (8512, 11648, 3)
# patches.shape=(1976, 224, 224, 3) , num_w=52, num_h=38
#
# 017_03 (81/506):
#
# Original shape: torch.Size([8866, 7938, 3])
# New shape: (8960, 8064, 3)
# patches.shape=(1440, 224, 224, 3) , num_w=36, num_h=40
#
# 017_04 (82/506):
#
# Original shape: torch.Size([7613, 11227, 3])
# New shape: (7616, 11424, 3)
# patches.shape=(1734, 224, 224, 3) , num_w=51, num_h=34
#
# 017_05 (83/506):
#
# Original shape: torch.Size([9602, 8646, 3])
# New shape: (9632, 8736, 3)
# patches.shape=(1677, 224, 224, 3) , num_w=39, num_h=43
#
# 017_06 (84/506):
#
# Original shape: torch.Size([9866, 10808, 3])
# New shape: (10080, 10976, 3)
# patches.shape=(2205, 224, 224, 3) , num_w=49, num_h=45
#
# 018_01 (85/506):
#
# Original shape: torch.Size([6905, 6088, 3])
# New shape: (6944, 6272, 3)
# patches.shape=(868, 224, 224, 3) , num_w=28, num_h=31
#
# 018_02 (86/506):
#
# Original shape: torch.Size([5271, 5615, 3])
# New shape: (5376, 5824, 3)
# patches.shape=(624, 224, 224, 3) , num_w=26, num_h=24
#
# 018_03 (87/506):
#
# Original shape: torch.Size([6831, 9731, 3])
# New shape: (6944, 9856, 3)
# patches.shape=(1364, 224, 224, 3) , num_w=44, num_h=31
#
# 018_04 (88/506):
#
# Original shape: torch.Size([8442, 8176, 3])
# New shape: (8512, 8288, 3)
# patches.shape=(1406, 224, 224, 3) , num_w=37, num_h=38
#
# 018_05 (89/506):
#
# Original shape: torch.Size([5455, 9521, 3])
# New shape: (5600, 9632, 3)
# patches.shape=(1075, 224, 224, 3) , num_w=43, num_h=25
#
# 018_06 (90/506):
#
# Original shape: torch.Size([8444, 6303, 3])
# New shape: (8512, 6496, 3)
# patches.shape=(1102, 224, 224, 3) , num_w=29, num_h=38
#
# 018_07 (91/506):
#
# Original shape: torch.Size([9393, 7036, 3])
# New shape: (9408, 7168, 3)
# patches.shape=(1344, 224, 224, 3) , num_w=32, num_h=42
#
# 018_08 (92/506):
#
# Original shape: torch.Size([12310, 10408, 3])
# New shape: (12320, 10528, 3)
# patches.shape=(2585, 224, 224, 3) , num_w=47, num_h=55
#
# 018_09 (93/506):
#
# Original shape: torch.Size([10156, 8825, 3])
# New shape: (10304, 8960, 3)
# patches.shape=(1840, 224, 224, 3) , num_w=40, num_h=46
#
# 018_10 (94/506):
#
# Original shape: torch.Size([5628, 2331, 3])
# New shape: (5824, 2464, 3)
# patches.shape=(286, 224, 224, 3) , num_w=11, num_h=26
#
# 018_11 (95/506):
#
# Original shape: torch.Size([6877, 5615, 3])
# New shape: (6944, 5824, 3)
# patches.shape=(806, 224, 224, 3) , num_w=26, num_h=31
#
# 018_12 (96/506):
#
# Original shape: torch.Size([10156, 8825, 3])
# New shape: (10304, 8960, 3)
# patches.shape=(1840, 224, 224, 3) , num_w=40, num_h=46
#
# 019_01 (97/506):
#
# Original shape: torch.Size([7094, 9347, 3])
# New shape: (7168, 9408, 3)
# patches.shape=(1344, 224, 224, 3) , num_w=42, num_h=32
#
# 019_02 (98/506):
#
# Original shape: torch.Size([4932, 6043, 3])
# New shape: (5152, 6048, 3)
# patches.shape=(621, 224, 224, 3) , num_w=27, num_h=23
#
# 019_03 (99/506):
#
# Original shape: torch.Size([4630, 11502, 3])
# New shape: (4704, 11648, 3)
# patches.shape=(1092, 224, 224, 3) , num_w=52, num_h=21
#
# 019_04 (100/506):
#
# Original shape: torch.Size([9460, 9875, 3])
# New shape: (9632, 10080, 3)
# patches.shape=(1935, 224, 224, 3) , num_w=45, num_h=43
#
# 019_05 (101/506):
#
# Original shape: torch.Size([5539, 4511, 3])
# New shape: (5600, 4704, 3)
# patches.shape=(525, 224, 224, 3) , num_w=21, num_h=25
#
# 019_06 (102/506):
#
# Original shape: torch.Size([14784, 14821, 3])
# New shape: (14784, 15008, 3)
# patches.shape=(4422, 224, 224, 3) , num_w=67, num_h=66
#
# 019_07 (103/506):
#
# Original shape: torch.Size([13638, 14006, 3])
# New shape: (13664, 14112, 3)
# patches.shape=(3843, 224, 224, 3) , num_w=63, num_h=61

# %%
all_patients_dict.keys()
# Out:
# dict_keys(['001_01', '001_02', '001_03', '001_04', '001_05', '001_06', '002_01', '002_02', '002_03', '002_04', '003_01', '003_02', '004_01', '004_02', '004_03', '004_04', '005_01', '005_02', '005_03', '005_04', '006_01', '006_02', '006_03', '006_04', '006_05', '007_01', '007_02', '007_03', '007_04', '008_01', '008_02', '008_03', '008_04', '008_05', '009_01', '009_02', '009_03', '009_04', '009_05', '010_01', '010_02', '010_03', '010_04', '010_05', '010_06', '011_01', '011_02', '011_03', '011_04', '012_01', '012_02', '012_03', '012_04', '012_05', '013_01', '013_02', '013_03', '013_04', '013_05', '014_01', '014_02', '014_03', '014_04', '014_05', '014_06', '015_01', '015_02', '015_03', '015_04', '015_05', '015_06', '016_01', '016_02', '016_03', '016_04', '016_05', '016_06', '016_07', '017_01', '017_02', '017_03', '017_04', '017_05', '017_06', '018_01', '018_02', '018_03', '018_04', '018_05', '018_06', '018_07', '018_08', '018_09', '018_10', '018_11', '018_12', '019_01', '019_02', '019_03', '019_04', '019_05', '019_06', '019_07', '020_01', '020_02', '020_03', '020_04', '020_05', '020_06', '020_07', '020_08', '020_09', '021_01', '021_02', '021_03', '021_04', '022_01', '022_02', '022_03', '022_04', '022_05', '022_06', '023_01', '023_02', '023_03', '023_04', '023_05', '023_06', '023_07', '024_01', '024_02', '024_03', '024_04', '024_05', '024_06', '025_01', '025_02', '025_03', '025_04', '026_01', '026_02', '026_03', '026_04', '026_05', '027_01', '027_02', '027_03', '027_04', '027_05', '027_06', '028_01', '028_02', '028_03', '028_04', '028_05', '029_01', '029_02', '029_03', '029_04', '029_05', '030_01', '030_02', '030_03', '030_04', '030_05', '030_06', '031_01', '031_02', '031_03', '031_04', '031_05', '031_06', '032_01', '032_02', '032_03', '032_04', '032_05', '032_06', '033_01', '033_02', '033_03', '033_04', '034_01', '034_02', '034_03', '034_04', '034_05', '035_01', '035_02', '035_03', '035_04', '035_05', '036_01', '036_02', '036_03', '036_04', '037_01', '037_02', '037_03', '037_04', '037_05', '038_01', '038_02', '038_03', '038_04', '038_05', '039_01', '039_02', '039_03', '039_04', '040_01', '040_02', '040_03', '040_04', '040_05', '040_06', '041_01', '041_02', '041_03', '041_04', '041_05', '041_06', '042_01', '042_02', '042_03', '042_04', '043_01', '043_02', '043_03', '044_01', '044_02', '044_03', '044_04', '044_05', '044_06', '045_01', '045_02', '045_03', '045_04', '046_01', '046_02', '046_03', '046_04', '046_05', '046_06', '046_07', '046_08', '046_09', '047_01', '047_02', '047_03', '047_04', '047_05', '047_06', '047_07', '047_08', '047_09', '048_01', '048_02', '048_03', '048_04', '048_05', '048_06', '049_01', '049_02', '049_03', '049_04', '049_05', '050_01', '050_02', '050_03', '050_04', '050_05', '050_06', '051_01', '051_02', '051_03', '052_01', '052_02', '052_03', '052_04', '052_05', '052_06', '052_07', '052_08', '053_01', '053_02', '053_03', '053_04', '053_05', '053_06', '053_07', '053_08', '053_09', '054_01', '054_02', '054_03', '054_04', '055_01', '055_02', '055_03', '055_04', '055_05', '056_01', '056_02', '056_03', '057_01', '057_02', '057_03', '057_04', '057_05', '058_01', '058_02', '058_03', '058_04', '058_05', '059_01', '059_02', '059_03', '059_04', '060_01', '060_02', '060_03', '060_04', '060_05', '061_01', '061_02', '061_03', '062_01', '062_02', '062_03', '063_01', '063_02', '063_03', '063_04', '063_05', '063_06', '064_01', '064_02', '064_03', '064_04', '065_01', '065_02', '065_03', '065_04', '065_05', '065_06', '066_01', '066_02', '066_03', '066_04', '066_05', '066_06', '067_01', '067_02', '067_03', '067_04', '067_05', '067_06', '067_07', '068_01', '068_02', '068_03', '068_04', '068_05', '069_01', '069_02', '069_03', '069_04', '069_05', '069_06', '070_01', '070_02', '070_03', '070_04', '070_05', '070_06', '070_07', '070_08', '071_01', '071_02', '071_03', '071_04', '071_05', '071_06', '071_07', '072_01', '072_02', '072_03', '072_04', '073_01', '073_02', '073_03', '073_04', '073_05', '073_06', '073_07', '073_08', '074_01', ...

# %%
torch.save(all_patients_dict, './data/adj_graph/img_dict.pth')

# %%
temp = all_patients_dict

# %%
all_patients_dict = torch.load('./data/adj_graph/img_dict.pth')

# %%
invalid_patients = []
for patient in all_patients_dict.keys():
    src, dest = all_patients_dict[patient]['edge_list']
    all_imgs = all_patients_dict[patient]['enc']

    edge_index = torch.tensor([src, dest], dtype=torch.long)
    x = all_imgs

    data = Data(x=x, edge_index=edge_index.contiguous()).to(device)
    
#     print(f'{patient}: {data.validate(raise_on_error=True)=}')
    
    if not data.validate(raise_on_error=True):
        invalid_patients.append(patient)

print(f'{invalid_patients=}')
# Out:
# invalid_patients=[]
